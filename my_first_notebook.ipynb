# %% [markdown]
# Hardware refers to the physical, tangible components of a computer system that you can touch and see. Software consists of intangible instructions, programs, and data that tell the hardware what to do.
# Examples of Hardware:Keyboard, Mouse, Scanner
# Examples of Software: Operating Systems, Application Software
